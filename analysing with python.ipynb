# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cars_1.csv")
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu     NaN         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
df.loc[[98,68,16]]
# Out:
#                          Car MPG Cylinders Displacement Horsepower Weight  \
# 98  Mercury Marquis Brougham  12         8          429        198   4952
# 68            Chevrolet Vega  20         4          140         90   2408
# 16       Dodge Challenger SE  15         8          383        170   3563
#
#    Acceleration Model Origin
# 98         11.5    73     US
# 68         19.5    72     US
# 16           10    70     US

# %%
df.describe()
# Out:
#                    Car  MPG Cylinders Displacement Horsepower Weight  \
# count              407  406       407          407        407    406
# unique             309  131         6           84         95    356
# top     Toyota Corolla   13         4           97        150   2130
# freq                 9   20       207           22         22      4
#
#        Acceleration Model Origin
# count           407   407    407
# unique           97    14      4
# top            14.5    73     US
# freq             23    40    254

# %%
df.dropna()
# Out:
#                     Car     MPG Cylinders Displacement Horsepower  Weight  \
# 0                STRING  DOUBLE       INT       DOUBLE     DOUBLE  DOUBLE
# 2     Buick Skylark 320      15         8          350        165    3693
# 3    Plymouth Satellite      18         8          318        150    3436
# 4         AMC Rebel SST      16         8          304        150    3433
# 5           Ford Torino      17         8          302        140    3449
# ..                  ...     ...       ...          ...        ...     ...
# 402     Ford Mustang GL      27         4          140         86    2790
# 403   Volkswagen Pickup      44         4           97         52    2130
# 404       Dodge Rampage      32         4          135         84    2295
# 405         Ford Ranger      28         4          120         79    2625
# 406          Chevy S-10      31         4          119         82    2720
#
#     Acceleration Model  Origin
# 0         DOUBLE   INT     CAT
# ...

# %%
vs = df.fillna(method="ffill")
vs
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu  DOUBLE         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
sd= df.fillna(method="bfill")
sd
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu      15         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
df.head(15)
# Out:
#                                  Car     MPG Cylinders Displacement  \
# 0                             STRING  DOUBLE       INT       DOUBLE
# 1          Chevrolet Chevelle Malibu     NaN         8          307
# 2                  Buick Skylark 320      15         8          350
# 3                 Plymouth Satellite      18         8          318
# 4                      AMC Rebel SST      16         8          304
# 5                        Ford Torino      17         8          302
# 6                   Ford Galaxie 500      15         8          429
# 7                   Chevrolet Impala      14         8          454
# 8                  Plymouth Fury iii      14         8          440
# 9                   Pontiac Catalina      14         8          455
# 10                AMC Ambassador DPL      15         8          390
# 11              Citroen DS-21 Pallas       0         4          133
# 12  Chevrolet Chevelle Concours (sw)       0         8          350
# ...

# %%
df.tail(13)
# Out:
#                                    Car MPG Cylinders Displacement Horsepower  \
# 394                      Datsun 310 GX  38         4           91         67
# 395              Buick Century Limited  25         6          181        110
# 396  Oldsmobile Cutlass Ciera (diesel)  38         6          262         85
# 397         Chrysler Lebaron Medallion  26         4          156         92
# 398                     Ford Grenada l  22         6          232        112
# 399                   Toyota Celica GT  32         4          144         96
# 400                  Dodge Charger 2.2  36         4          135         84
# 401                   Chevrolet Camaro  27         4          151         90
# 402                    Ford Mustang GL  27         4          140         86
# 403                  Volkswagen Pickup  44         4           97         52
# 404                      Dodge Rampage  32         4          135         84
# ...

# %%
sm= df.replace(310,0)
sm
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu     NaN         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
disp=[307,350,318,304,140]
hp=[130,165,150,150,86]
plt.plot(disp,hp,marker="o",ls= "dotted",c="green")
plt.grid()
plt.show()
